# %%
print("Hello, World!")

# %%
print('Crazy Human')

# %%
print(7)

# %%
print(7.7)

# %%
print(True)

# %%
print("hello",1,7.7,False)

# %%
print("hello", 2, 5.6, True, sep='-')

# %%
print("hello")
print("Wrold")

# %%
print("hello", end=' ')
print("World")

# %%
# Data Type
print(8) # integer

# %%
print(4.5) # Float/ Decimal

# %%
# Boolean 
print(True)
print(False)

# %%
# Text/String 
print("Hello world")

# %%
# complex number 
print(3 + 5j)

# %%
print([1,2,3,4]) # list

# %%
# tuple 
print((1,2,3,4,5))

# %%
# sets 
print({1,2,3,3,4})

# %%
# dictionary 
print({'name': 'monkey', 'age': 30})

# %%
# type 
type([1,2,3,4])

# %%
# Variable 
name = 'monkey'
print(name)

a = 5 
b = 6 

print(a + b)

# %%
# Dynamic Typing 
a = 5 

# static typing 
int b = 6

# %%
a = 1
b = 2
c = 3

print(a,b,c)

# %%
a,b,c = 1,2,3

print(a,b,c)

# %%
a=b=c = 5
print(a,b,c)

# %%
name1 = "Mango"
print(name1)

_ = "orange"
print(_)

# %%
# user input
input("Enter email")

# %%
fnum = int(input('Enter first number'))
snum = int(input("Enter Second Number"))

result = fnum + snum

print(result)

# %%
# Operations in Python

# Arithematric operations 
print(4+6)

print(3-6)

print(3*3)

print(8/2)

print(8//2)

print(10%3)

print(2**2)

# %%
# Relational Operators 

print(4 > 5)

print(4 < 5)

print(4 >= 5)

print(4 <= 5)

print(4 == 4)

print(4 != 4)

# %%
# logical operators 

print(1 and 0)

print(1 or 0)

print(not 1)

# %%
# Bitwise Operators 

print(1 & 0)

print(1 | 0)

print(2 ^ 1)

print(~1)

print(4 >> 2)

print(4 << 2)

# %%
# Membership Operators 

print('D' not in 'Delhi')

print(1 in [2,3,4,2,1,6])

# %%
number = int(input("Enter a 3 digit number"))

a = number%10

number = number//10

b = number%10

number = number//10

c = number%10

print(a + b + c)

# %%
# if - else in python

email = input("Enter Email")
password = input("Enter password")

if email == 'gorila@gmail.com' and password == '12345':
    print("login sucessfull")
elif email == 'gorila@gmail.com' and password != '12345':
    print('Incorrect Password Try again')
    i = 0
    while (i < 3):
        password = input("enter Password again")
        if password == '12345':
            print('login sucessfull')
        else:
            print('Try again',i)
            i+= 1
else:
    print('3 attemt Failed account is blocked')

# %%
a = int(input("Enter first number"))
b = int(input("Enter second Number"))
c = int(input("Enter Third Number"))

if a > b and a > c :
    print("a is greater")
elif b > a and b > c:
    print('b is greater')
else:
    print("c is greater")

# %%
menu = input('''
Hi how can i help you.
1. Enter 1 for pin change
2. Enter 2 for balance check
3. Enter 3 for withdrawl
4. exit''')

if menu == '1':
    print('Pin change')
elif menu == '2':
    print('Balance check')
elif menu == '3':
    print("withdrowl")
else:
    print('exit')

# %%
# Math 
import math 

math.sqrt(192)

# %%
import random 
print(random.randint(1,100))

# %%
import datetime

print(datetime.datetime.now())

# %%
number = int(input("Enter the Number"))

i = 1
while i < 11:
    print(number,'*',i, '=', number * i)
    i+=1
else:
    print('Table of =',number)

# %%
x = 1
while x < 3:
    print(x)
    x+=1
else:
    print("limit crossed")

# %%
import random
jackpot = random.randint(1,100)

guess = int(input("Guess Number"))
counter = 1
while guess != jackpot:
    if guess < jackpot:
        print("Guess Higher")
    else:
        print("Guess Lower")

    guess = int(input("Guess Number"))
    counter += 1

else:
    print("correct Guess")
    print("attemts", counter)
# Out:
# Guess Higher
# Guess Higher
# Guess Higher
# Guess Lower
# Guess Higher
# Guess Lower
# correct Guess
# attemts 7

# %%
for i in {1,2,3,4,6,7,8,9}:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
curr_pop = 100000

for i in range(10,0,-1):
    print(i,'=',curr_pop)
    curr_pop = curr_pop - 0.1*curr_pop
# Out:
# 10 = 100000
# 9 = 90000.0
# 8 = 81000.0
# 7 = 72900.0
# 6 = 65610.0
# 5 = 59049.0
# 4 = 53144.1
# 3 = 47829.69
# 2 = 43046.721000000005
# 1 = 38742.0489

# %%
curr_pop = 100

for i in range(10,0,-1):
    print(i, '=', curr_pop)
    curr_pop /= 1.1
# Out:
# 10 = 100
# 9 = 90.9090909090909
# 8 = 82.64462809917354
# 7 = 75.13148009015777
# 6 = 68.30134553650706
# 5 = 62.0921323059155
# 4 = 56.44739300537772
# 3 = 51.31581182307065
# 2 = 46.650738020973314
# 1 = 42.40976183724847
